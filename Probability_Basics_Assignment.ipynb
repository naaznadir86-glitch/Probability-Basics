# %%
# Probability Basics

# %% [markdown]
# #1. Dice Probability
# # Ans. A dice basically has six sides where it has numbers from 1 to 6 i.e.      1,2,3,4,5,6
#     A - Even Numbers on dice 2,4,6 probability=3/6 =1/2 So the probability for even numbers =1/2
#
#     B - A number greater than 4 refers to 5 and 6 so only two numbers are greater than 4 so 2/6=1/3

# %% [markdown]
# # 2. 50 Students
# # Ans. 20-Maths,15-Science,5-Both subjects
#        =20+15-5
#        =30
#
#        Probability= 30/50=3/5
#                   =0.6

# %% [markdown]
# #3. Red and Blue balls
#  #Ans. There are 3 red balls and 2 blue balls.
#        first ball drawn is red
#        probability of next ball being red=?
#        Total balls =5
#        balls red =2
#        balls blue =3
#        new red ball=5-1=4
#        new blue ball=5-3=2
#        probability =2/4=1/2

# %% [markdown]
# # 4. School Population
# # Ans. 60% BOYS AND 40% GIRLS
#        Should use strata of girls and boys as 50/50 to ensure stratified sampling  though there is difference but sample reffered will distribute equally

# %% [markdown]
# #5. Height of 1000 Students
# # Ans. Mean height of population of 1000 students  = 160cm
#        Mean height of sample of 100 students = 158 cm
#        population - sample = 160-158=2
#        Error = 2cm

# %% [markdown]
# #7. 100 students sport
# # Ans. Cricket+ Football -both
#        C+F+both
#       =40+30-10
#       =60

# %% [markdown]
# # 10. Discrete
# Ans.  1.countable
#       2.Hen laying eggs in a day
#       3.Number of emails received in 24 hours
#
#       Continuous
#       1.Any value
#       2. Record of temperature
#       3. Record of flights every Thursday
